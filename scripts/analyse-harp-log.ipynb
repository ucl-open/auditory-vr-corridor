# %%
import harp
import matplotlib.pyplot as plt

plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False

# %%
reader = harp.create_reader(r"..\src\DataSchemas\device.yml")
analogData_df = reader.AnalogData.read(r"..\Logs\sub-Algernon\ses-two_date-2026-05-07T14-56-02\Behavior_44\Behavior_442026-05-07T15_56_02.bin")
analogData_df.head()
# Out:
#               AnalogInput0  Encoder  AnalogInput1
# Time
# 3.861011e+09             4        0             5
# 3.861011e+09             3        0             6
# 3.861011e+09             5        0             5
# 3.861011e+09             5        0             4
# 3.861011e+09             3        0             4

# %%
plt.plot(analogData_df.Encoder.values)
plt.show()
